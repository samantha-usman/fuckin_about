# %%
import numpy
from matplotlib import pyplot as plt
import cmath
import sys
sys.path
sys.path.append('/Users/samanthausman/zerk/lib/python2.7/site-packages')
sys.path.append('/Users/samanthausman/lalsuite/lalsimulation')
import h5py
import lalsimulation

# %%
waveform = numpy.loadtxt("/Users/samanthausman/waveform.txt")

# %%
plt.plot(waveform[:,1])

# %%
for shift in range(0,1000, 5):
    plt.plot(numpy.append(waveform[:,1], numpy.zeros(shift))+numpy.append(numpy.zeros(shift),waveform[:,1]))
    plt.savefig("/Users/samanthausman/fuckin_about/%d.png"%shift)
    plt.close()

# %%
freq = numpy.fft.fft(waveform[:,1])

# %%
plt.plot(numpy.absolute(freq))

# %%
plt.plot(numpy.absolute(freq))
plt.xlim(0,80)
# Out:
# (0, 80)

# %%
plt.plot(numpy.absolute(freq))
plt.xlim(3360,3440)
# Out:
# (3360, 3440)

# %%
templateFile = h5py.File('template.hdf5', 'r')
template = templateFile['strain/Strain'][...]
temp_time = numpy.arange(0, template.size / (1.0*fs), 1./fs)
templateFile.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-194e2092091b> in <module>()
#       1 templateFile = h5py.File('template.hdf5', 'r')
#       2 template = templateFile['strain/Strain'][...]
# ----> 3 temp_time = numpy.arange(0, template.size / (1.0*fs), 1./fs)
#       4 templateFile.close()
#
# NameError: name 'fs' is not defined

# %%
plt.plot(temp_time, template)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-8ac19b01237a> in <module>()
# ----> 1 plt.plot(temp_time, template)
#
# NameError: name 'temp_time' is not defined

# %%
plt.plot(numpy.absolute(numpy.fft.fft(template)))
plt.xlim(0,400)

# %%
lalsimulation.fSEOBNRv4RD
